\x00\xa3+\x00\x00\x00\x00\x00\x00\x8d}\xd9r\x1bI\x92\xed\xfb5\xbb\xff\x90\xa6\x97f\x9b\xa1Q\xb9/\x8f \xb8I"E6)\x93l\xe6-\x08\x04\x81l&2\xd9\x99\x00U\xac\xaf\x1f\xdfb\x03\xa9\x99\xb62U\x95T\x15\x91\xb1\xf8r\xfc\xb8{\xf0NM\x93\xee7z\xfc\xbc\x9e\xdd\xad:\xf8\xdd\xec\x9b\xda\xe9\xd9\x83\xfes\xb6\xd8\xc0?\xdb\xc7\x87\x97\xd9\x9d\x1aW\xdb\xd9\xf7v\xf5\xac\xf7\xb3\x0b5\xea\xd9R=\xb6\xfd\xec|\xf7\xa8\xc6g\xbd\xfe\xff\xff\xafn\xd2Y6\xfb\xf4Uw\xdd\xdb,\xba\x19\xe7\xd1\x17\x98f\xfa4\xdb\xa9N\xcf\xb2|^\xccb\xf8+\xcb\xe2&If\xd5\xbcNa\xc0\xec\x9f80\xc3\x81?\xdb\xeeYO8r\x92\xa1\xd1\xc9y\xd7\xe9>\xfa\xa6\xf5z\xfa\xfb\xa7\xd9\x93\xa6\xa9\xf2j\x96\xe0De\x96V\xe9\xac\x9a\xcd\x1ep\x8e|\x96\xce>\xdd\xbcu<\xc5<\xfa\xbe\x1dvj\x8a.F\xd5\xafZ\xb3\x8a2\xa55\xa4y\x9cV\xe5\xac\x99\x97uU\xc8\x1a\n^\xc3\xf8\x17\x0f_t\x8fz\xdc\xcb\xb0\xb4\xe2\xa5\'ER\xe4\xb3z^\x96i!\x9f-q\xd8U;\xbe\x0e\xbd\xeee\xf1\x8bN\xff\xa9\xfa\xb5\x1e\xa3\x93+\xddmTt\x1e]\xb7\xfd\xfa\xdf\xaf\xed\xb4w\xdbHS\xd8F\x02\x93\xc6I\xda\xd4\xb3$\x9d\xa7\x ...

# %%
import os
import zipfile

local_zip='/content/titanic.zip'
zip_ref=zipfile.ZipFile(local_zip,'r')
zip_ref.extractall('/tmp/')
zip_ref.close()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
train=pd.read_csv('/tmp/train.csv')
test=pd.read_csv('/tmp/test.csv')

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0            1         0       3  ...   7.2500   NaN         S
# 1            2         1       1  ...  71.2833   C85         C
# 2            3         1       3  ...   7.9250   NaN         S
# 3            4         1       1  ...  53.1000  C123         S
# 4            5         0       3  ...   8.0500   NaN         S
#
# [5 rows x 12 columns]

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
train.describe()
# Out:
#        PassengerId    Survived      Pclass  ...       SibSp       Parch        Fare
# count   891.000000  891.000000  891.000000  ...  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642  ...    0.523008    0.381594   32.204208
# std     257.353842    0.486592    0.836071  ...    1.102743    0.806057   49.693429
# min       1.000000    0.000000    1.000000  ...    0.000000    0.000000    0.000000
# 25%     223.500000    0.000000    2.000000  ...    0.000000    0.000000    7.910400
# 50%     446.000000    0.000000    3.000000  ...    0.000000    0.000000   14.454200
# 75%     668.500000    1.000000    3.000000  ...    1.000000    0.000000   31.000000
# max     891.000000    1.000000    3.000000  ...    8.000000    6.000000  512.329200
#
# [8 rows x 7 columns]

# %%
import seaborn as sns
sns.heatmap(train.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
sns.countplot(x='Survived',data=train)

# %%
sns.countplot(x='Survived',hue='Sex',data=train)

# %%
sns.countplot(x='Survived',hue='Pclass',data=train)

# %%
sns.distplot(train['Fare'],bins=40)

# %%
sns.distplot(train['Age'],bins=40)

# %%
sns.countplot(x='SibSp',data=train)

# %%
sns.countplot(x='SibSp',hue='Survived',data=train)

# %%
sns.countplot(x='Parch',data=train)

# %%
sns.countplot(x='Parch',hue='Survived',data=train)

# %%
sns.pairplot(train,hue='Survived')
